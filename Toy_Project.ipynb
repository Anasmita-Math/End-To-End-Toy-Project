# %% [markdown]
# # End To End Toy Project With Placement Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Downloads/placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %% [markdown]
# ***Scatter Ploting***

# %%
plt.figure(figsize=(5,4))
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])
plt.show()

# %%
x=df.iloc[:,0:2]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 28   5.2   90.0
# 59   4.8  112.0
# 53   8.3  168.0
# 71   6.1  132.0
# 90   7.3   86.0
# ..   ...    ...
# 47   5.2  161.0
# 35   6.8   90.0
# 80   4.9  196.0
# 7    5.0   63.0
# 62   6.0  102.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 93   6.8  112.0
# 11   6.9  138.0
# 58   8.0   79.0
# 72   7.3  116.0
# 21   7.1  151.0
# 50   3.5  233.0
# 65   8.1  166.0
# 82   6.5   37.0
# 83   7.5  130.0
# 24   4.7  121.0

# %%
y_train
# Out:
# 28    0
# 59    0
# 53    1
# 71    1
# 90    1
#      ..
# 47    0
# 35    1
# 80    0
# 7     0
# 62    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 93    1
# 11    1
# 58    1
# 72    1
# 21    1
# 50    0
# 65    1
# 82    1
# 83    1
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-6.63360900e-01, -8.58340678e-01],
#        [-1.03246434e+00, -2.87075286e-01],
#        [ 2.19719074e+00,  1.16705480e+00],
#        [ 1.67121834e-01,  2.32256889e-01],
#        [ 1.27443215e+00, -9.62207113e-01],
#        [ 7.48459748e-02, -1.48153929e+00],
#        [-8.47912618e-01, -8.32374070e-01],
#        [ 2.01263902e+00,  6.73689238e-01],
#        [-9.40188477e-01,  2.84190107e-01],
#        [ 1.67121834e-01,  8.55455500e-01],
#        [-2.41660223e+00,  1.55655394e+00],
#        [ 8.13052849e-01, -1.44258938e-03],
#        [-1.03246434e+00,  4.65956368e-01],
#        [-6.63360900e-01,  2.62118490e+00],
#        [-7.55636759e-01, -1.48153929e+00],
#        [-4.78809181e-01,  3.10156716e-01],
#        [ 8.13052849e-01,  4.65956368e-01],
#        [ 1.55125972e+00,  1.28390454e-01],
#        [ 1.36670800e+00,  2.32256889e-01],
#        [ 1.45898386e+00,  9.07388717e-01],
#        [-7.55636759e-01,  1.28390454e-01],
#        [ 7.20776990e-01,  8.03522282e-01],
#        [ 1.67121834e-01, -1.09204016e+00],
#        [ 1.27443215e+00,  3.62089933e-01],
#        [ 2.38174246e+00, -7.93424157e-02],
#        [ 9.97604568e-01,  1.97201968e+00],
#        [ 1.73581144e+00, -2.35142068e-01],
#        [ 6.28501130e-01,  3.88056542e-01],
#        [-1.77067121e+00, -1.24783981e+00],
#        [ 3.51673553e-01, -5.20774765e-01],
#        [ 6.28501130e-01, -7.93424157e-02],
#        [-1.74298845e-02, -4.42874938e-01],
#        [ 9.97604568e-01,  1.34882107e+00],
#        [ 5.36225271e-01, -8.58340678e-01],
#        [-4.78809181e-01,  4.14023151e-01],
#        [ 1.27443215e+00, -1.89700503e+00],
#        [-7.55636759e-01,  1.37478767e+00],
#        [ 1.08988043e+00, -1.94893825e+00],
#        [ 4.43949412e-01, -1.83208851e-01],
#        [-1.77067121e+00, -5.98674591e-01],
#        [-2.01981603e-01,  2.32256889e-01],
#        [ 5.36225271e-01,  1.80323672e-01],
#        [ 1.45898386e+00, -1.61137233e+00],
#        [ 7.48459748e-02,  2.45240194e-02],
#        [ 9.05328708e-01, -7.02541026e-01],
#        [ 7.20776990e-01,  1.53058733e+00],
#        [-1.21701606e+00,  5.95789412e-01],
#        [ 9.05328708e-01,  4.14023151e-01],
#        [-1.12474020e+00, -9.36240505e-01],
#        [-1.40156777e+00,  6.73689238e-01],
#        [-4.78809181e-01, -4.16908330e-01],
#        [-1.40156777e+00, -2.10473790e+00],
#        [ 1.67121834e-01, -1.50750590e+00],
#        [-9.40188477e-01,  8.29488891e-01],
#        [-8.47912618e-01, -1.31275633e-01],
#        [ 1.55125972e+00, -8.84307287e-01],
#        [-1.49384363e+00,  1.99798629e+00],
#        [-1.03246434e+00,  1.03722176e+00],
#        [-2.01981603e-01,  4.39989760e-01],
#        [ 4.43949412e-01,  4.65956368e-01],
#        [-6.63360900e-01, -3.39008503e-01],
#        [ 7.48459748e-02, -2.02683807e+00],
#        [-1.09705744e-01,  1.11512159e+00],
#        [-1.12474020e+00, -1.84507181e+00],
#        [-9.40188477e-01, -1.61137233e+00],
#        [ 5.36225271e-01,  9.59321935e-01],
#        [ 9.97604568e-01, -2.87075286e-01],
#        [ 2.59397693e-01, -2.61108677e-01],
#        [ 9.97604568e-01,  4.14023151e-01],
#        [ 3.51673553e-01,  1.02423846e-01],
#        [-1.86294707e+00, -3.64975112e-01],
#        [-9.40188477e-01,  7.25622456e-01],
#        [ 7.48459748e-02,  6.73689238e-01],
#        [-9.40188477e-01, -7.93424157e-02],
#        [-6.63360900e-01,  2.32256889e-01],
#        [ 1.67121834e-01, -5.20774765e-01],
#        [-1.09705744e-01,  4.91922977e-01],
#        [ 9.97604568e-01, -1.53347251e+00],
#        [ 3.51673553e-01,  1.28390454e-01],
#        [-5.71085040e-01, -5.33758069e-02],
#        [-4.78809181e-01, -2.35142068e-01],
#        [-1.03246434e+00,  1.19302141e+00],
#        [-5.71085040e-01, -2.35142068e-01],
#        [-2.01981603e-01,  5.17889586e-01],
#        [-2.01981603e-01,  1.19302141e+00],
#        [-6.63360900e-01,  9.85288543e-01],
#        [ 8.13052849e-01, -8.58340678e-01],
#        [-9.40188477e-01,  1.89411985e+00],
#        [-8.47912618e-01, -1.55943911e+00],
#        [ 7.48459748e-02, -5.46741373e-01]])

# %%
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[ 0.11575982, -0.33112508],
#        [ 0.1881097 ,  0.1970499 ],
#        [ 0.98395844, -1.00150101],
#        [ 0.47750924, -0.24986739],
#        [ 0.33280947,  0.46113738],
#        [-2.27178639,  2.12692   ],
#        [ 1.05630832,  0.76585372],
#        [-0.10128984, -1.85470674],
#        [ 0.62220901,  0.03453452],
#        [-1.40358777, -0.14829528]])

# %% [markdown]
# ***Train the model using Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ***Model Evaluation***

# %%
y_pred=clf.predict(x_test)
y_test
# Out:
# 93    1
# 11    1
# 58    1
# 72    1
# 21    1
# 50    0
# 65    1
# 82    1
# 83    1
# 24    0
# Name: placement, dtype: int64

# %% [markdown]
# ***Accuracy Evaluation***

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
# Plotting decision regions
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# Requirement already satisfied: mlxtend in c:\users\matha\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\matha\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matha\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\matha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# <Axes: >
